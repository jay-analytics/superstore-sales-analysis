# %% [markdown]
# # Superstore Sales Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("SuperStore_Sales_Clean.csv")
df.head()
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0    4918  CA-2019-160304   1/1/2019  1/7/2019  Standard Class    BM-11575
# 1    4919  CA-2019-160304   1/2/2019  1/7/2019  Standard Class    BM-11575
# 2    4920  CA-2019-160304   1/2/2019  1/7/2019  Standard Class    BM-11575
# 3    3074  CA-2019-125206   1/3/2019  1/5/2019     First Class    LR-16915
# 4    8604  US-2019-116365   1/3/2019  1/8/2019  Standard Class    CA-12310
#
#        Customer Name    Segment        Country          City  ...   Region  \
# 0      Brendan Murry  Corporate  United States  Gaithersburg  ...     East
# 1      Brendan Murry  Corporate  United States  Gaithersburg  ...     East
# 2      Brendan Murry  Corporate  United States  Gaithersburg  ...     East
# 3       Lena Radford   Consumer  United States   Los Angeles  ...     West
# 4  Christine Abelman  Corporate  United States   San Antonio  ...  Central
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         5901 non-null   int64
#  1   Order ID       5901 non-null   object
#  2   Order Date     5901 non-null   object
#  3   Ship Date      5901 non-null   object
#  4   Ship Mode      5901 non-null   object
#  5   Customer ID    5901 non-null   object
#  6   Customer Name  5901 non-null   object
#  7   Segment        5901 non-null   object
#  8   Country        5901 non-null   object
#  9   City           5901 non-null   object
#  10  State          5901 non-null   object
#  11  Region         5901 non-null   object
#  12  Product ID     5901 non-null   object
#  13  Category       5901 non-null   object
#  14  Sub-Category   5901 non-null   object
#  15  Product Name   5901 non-null   object
#  16  Sales          5901 non-null   float64
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce', dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce', dayfirst=True)

# %%
df = df.dropna(subset=['Order Date','Ship Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1685 entries, 0 to 5677
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         1685 non-null   int64
#  1   Order ID       1685 non-null   object
#  2   Order Date     1685 non-null   datetime64[ns]
#  3   Ship Date      1685 non-null   datetime64[ns]
#  4   Ship Mode      1685 non-null   object
#  5   Customer ID    1685 non-null   object
#  6   Customer Name  1685 non-null   object
#  7   Segment        1685 non-null   object
#  8   Country        1685 non-null   object
#  9   City           1685 non-null   object
#  10  State          1685 non-null   object
#  11  Region         1685 non-null   object
#  12  Product ID     1685 non-null   object
#  13  Category       1685 non-null   object
#  14  Sub-Category   1685 non-null   object
#  15  Product Name   1685 non-null   object
#  16  Sales          1685 non-null   float64
# ...

# %%
df.sort_values(by="Profit").head(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 5037     684  US-2020-168116 2020-04-11 2020-04-11        Same Day
# 383     1200  CA-2019-130946 2019-08-04 2019-12-04  Standard Class
# 4702    5321  US-2020-162558 2020-02-10 2020-05-10     First Class
# 1700    7642  US-2019-157490 2019-06-10 2019-07-10     First Class
# 189     5199  CA-2019-103982 2019-03-03 2019-08-03  Standard Class
# 5480    1996  US-2020-147221 2020-02-12 2020-04-12    Second Class
# 1353     870  CA-2019-158099 2019-03-09 2019-05-09     First Class
# 5483    4498  CA-2020-155075 2020-02-12 2020-09-12  Standard Class
# 3293    8236  CA-2020-102204 2020-01-05 2020-06-05  Standard Class
# 2762    6567  CA-2020-131282 2020-05-02 2020-08-02    Second Class
#
#      Customer ID      Customer Name      Segment        Country          City  \
# 5037    GT-14635     Grant Thornton    Corporate  United States    Burlington
# ...

# %% [markdown]
# # High-Impact Analysis

# %% [markdown]
# # 1. Region Performance

# %%
df.groupby("Region")[["Sales","Profit"]].sum().sort_values(by="Sales", ascending=False)
# Out:
#              Sales    Profit
# Region
# West     156725.55  20963.89
# East     117035.15  19427.94
# Central   94118.66  13054.05
# South     77549.89   6007.62

# %% [markdown]
# # Profit Margin

# %%
region = df.groupby("Region")[["Sales","Profit"]].sum()
region["Profit Margin (%)"] = (region["Profit"] / region["Sales"]) * 100
region.sort_values(by="Profit Margin (%)")
# Out:
#              Sales    Profit  Profit Margin (%)
# Region
# South     77549.89   6007.62           7.746781
# West     156725.55  20963.89          13.376179
# Central   94118.66  13054.05          13.869779
# East     117035.15  19427.94          16.600090

# %% [markdown]
# # 2. Category Analysis

# %%
df.groupby("Category")[["Sales","Profit"]].sum()
# Out:
#                      Sales    Profit
# Category
# Furniture        127499.02   3158.28
# Office Supplies  161480.66  20618.25
# Technology       156449.57  35676.97

# %% [markdown]
# # 3. Sub-Category Analysis

# %%
df.groupby("Sub-Category")["Profit"].sum().sort_values()
# Out:
# Sub-Category
# Tables         -2536.08
# Supplies        -913.99
# Bookcases       -439.42
# Fasteners        145.48
# Furnishings      802.37
# Envelopes        890.90
# Labels           948.89
# Art             1072.24
# Appliances      3919.65
# Binders         4109.52
# Storage         4195.01
# Machines        4234.93
# Chairs          5331.41
# Phones          6084.17
# Paper           6250.55
# Accessories     8456.03
# Copiers        16901.84
# Name: Profit, dtype: float64

# %% [markdown]
# # 4. Top Loss-Making Products

# %%
df.sort_values(by="Profit").head(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 5037     684  US-2020-168116 2020-04-11 2020-04-11        Same Day
# 383     1200  CA-2019-130946 2019-08-04 2019-12-04  Standard Class
# 4702    5321  US-2020-162558 2020-02-10 2020-05-10     First Class
# 1700    7642  US-2019-157490 2019-06-10 2019-07-10     First Class
# 189     5199  CA-2019-103982 2019-03-03 2019-08-03  Standard Class
# 5480    1996  US-2020-147221 2020-02-12 2020-04-12    Second Class
# 1353     870  CA-2019-158099 2019-03-09 2019-05-09     First Class
# 5483    4498  CA-2020-155075 2020-02-12 2020-09-12  Standard Class
# 3293    8236  CA-2020-102204 2020-01-05 2020-06-05  Standard Class
# 2762    6567  CA-2020-131282 2020-05-02 2020-08-02    Second Class
#
#      Customer ID      Customer Name      Segment        Country          City  \
# 5037    GT-14635     Grant Thornton    Corporate  United States    Burlington
# ...

# %% [markdown]
# # 5. Returns Impact

# %%
df.groupby("Returns")["Profit"].mean()
# Out:
# Returns
# 0    35.258061
# 1    36.131400
# Name: Profit, dtype: float64

# %% [markdown]
# # 1. Profit by Category

# %%
df.groupby("Category")["Profit"].sum().plot(kind="bar", title="Profit by Category")
plt.show()

# %% [markdown]
# # 2. Sales by Region

# %%
df.groupby("Region")["Sales"].sum().plot(kind="bar", title="Sales by Region")
plt.show()

# %% [markdown]
# ## Insights
#
# # “Some regions generate high sales but lower profit margins, indicating inefficiency"
# # “Certain sub-categories consistently generate losses"
# # “Returned orders significantly reduce profitability”
# # “Few products are responsible for major losses”
